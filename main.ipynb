# %%
# %run main.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0, Batch 100, Average_Loss: 17.205
# Epoch 0, Batch 200, Average_Loss: 7.504
# Epoch 0, Batch 300, Average_Loss: 4.986
# Test Loss: 0.0370, Accuracy: 31.90%
# Epoch 1, Batch 100, Average_Loss: 3.237
# Epoch 1, Batch 200, Average_Loss: 3.319
# Epoch 1, Batch 300, Average_Loss: 2.148
# Test Loss: 0.0234, Accuracy: 39.81%
# Epoch 2, Batch 100, Average_Loss: 2.083
# Epoch 2, Batch 200, Average_Loss: 1.980
# Epoch 2, Batch 300, Average_Loss: 1.802
# Test Loss: 0.0169, Accuracy: 47.37%
# Epoch 3, Batch 100, Average_Loss: 1.636
# Epoch 3, Batch 200, Average_Loss: 1.653
# Epoch 3, Batch 300, Average_Loss: 1.513
# Test Loss: 0.0146, Accuracy: 53.10%
# Epoch 4, Batch 100, Average_Loss: 1.449
# Epoch 4, Batch 200, Average_Loss: 1.575
# Epoch 4, Batch 300, Average_Loss: 1.508
# Test Loss: 0.0144, Accuracy: 51.00%
# Epoch 5, Batch 100, Average_Loss: 1.347
# Epoch 5, Batch 200, Average_Loss: 1.337
# ...
